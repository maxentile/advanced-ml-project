# %%
import sys
sys.path.append('../scripts/')
from tpe import TPE

# %%
from scipy.cluster import hierarchy
from scipy.spatial import distance
from scipy.spatial.distance import squareform,pdist

# %%
from sklearn import datasets
data = datasets.load_digits()
X = data.data
Y = data.target

# %%
import numpy as np
import numpy.random as npr
n = len(X)
npr.seed(0)
rand = npr.rand(len(X))
ind = sorted(np.arange(len(X)),key=lambda i:rand[i])
X_s = X[ind][:n]
Y_s = Y[ind][:n]

# %%
from time import time

# %%
linkages = ['single','complete','ward','average','weighted','centroid','median']

# %%
tpe_res = dict()
t = time()
for linkage in linkages:
    tpe = TPE(linkage)
    tpe_res[linkage] = tpe.fit_transform(X_s)
    print(linkage)
    print(time() - t)
# Out:
# single
# 114.88511896133423
# complete
# 231.5691568851471
# ward
# 334.93058490753174
# average
# 451.37547993659973
# weighted
# 568.4442269802094
# centroid
# 685.3798639774323
# median
# 803.9474320411682

# %%
for linkage in linkages:
    np.save('results/approx_tpe/' + linkage + '.npy',tpe_res[linkage])

# %%
c = hierarchy.linkage(X_s,'single')

# %%
X_ = []
t = time()
for i in range(10):
    tpe = TPE()
    X_.append(tpe.fit_transform(X_s))
    print(i)
    print(time() - t)
# Out:
# 0
# 103.52206897735596
# 1
# 211.1367950439453
# 2
# 328.5524969100952
# 3
# 445.4194960594177
# 4
# 554.2865769863129
# 5
# 660.1430549621582
# 6
# 764.963103055954
# 7
# 878.1931459903717
# 8
# 990.8683819770813
# 9
# 1103.0635640621185

# %%
# save embeddings to disk

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def plot(X,Y,title='Embedding'):
    plt.scatter(X[:,0],X[:,1],c=Y,linewidths=0)
    plt.title(title)

# %%
for x in X_:
    plot(x,Y_s)
    plt.figure()

# %%
def compare_pairwise_distances(X1,X2):
    return np.sum((pdist(X1) - pdist(X2))**2)

# %%
C = [hierarchy.linkage(x,'single') for x in X_]

# %%
D = [hierarchy.cophenet(c) for c in C]

# %%
D_true = hierarchy.cophenet(c)

# %%
for d in D:
    plt.imshow(squareform(d),interpolation='none',cmap='Blues')
    plt.figure()

# %%
cophenetic_inconsistency = np.zeros((len(D),len(D)))
for i in range(len(D)):
    for j in range(len(D)):
        cophenetic_inconsistency[i,j] = np.sum((D[i]-D[j])**2)/len(D[i])
plt.imshow(cophenetic_inconsistency,interpolation='none',cmap='Blues')
plt.colorbar()

# %%
cophenetic_inaccuracy = np.zeros(len(D))
for i in range(len(D)):
    cophenetic_inaccuracy[i] = np.sum((D[i]-D_true*(D[i].mean() / D_true.mean()))**2)
#plt.imshow(cophenetic_inconsistency,interpolation='none',cmap='Blues')
#plt.colorbar()
plt.bar(range(len(D)),cophenetic_inaccuracy/len(D_true))
# Out:
# <Container object of 10 artists>

# %%
D[0],D_true*(D[0].mean() / D_true.mean())
# Out:
# (array([ 1.48623202,  1.48623202,  1.48623202, ...,  1.03512275,
#          1.12165145,  1.12165145]),
#  array([ 1.19420958,  1.19420958,  1.27029408, ...,  1.13525541,
#          1.27548109,  1.27548109]))

# %%
# how well does it preserve the relative cophenetic distances?
coph_order = np.array(sorted(np.arange(len(D_true)),key=lambda i:D_true[i]))

# %%
def order_of_distances(pairwise_distances):
    return np.array(sorted(np.arange(len(pairwise_distances)),
                           key=lambda i:pairwise_distances[i]))

# %%
from scipy.stats import spearmanr
order_of_distances(D_true),order_of_distances(D[0])
# Out:
# (array([1327940, 1228292, 1050474, ..., 1463825, 1463826, 1463827]),
#  array([ 333175, 1142600,  890378, ..., 1463825, 1463826, 1463827]))

# %%
sl_preservation = np.array([spearmanr(D_true,d) for d in D])
print(sl_preservation)
# Out:
# [[ 0.72605155  0.        ]
#  [ 0.84463853  0.        ]
#  [ 0.74095459  0.        ]
#  [ 0.64849082  0.        ]
#  [ 0.77313827  0.        ]
#  [ 0.69569552  0.        ]
#  [ 0.77674679  0.        ]
#  [ 0.86985208  0.        ]
#  [ 0.73824976  0.        ]
#  [ 0.78654176  0.        ]]

# %%
sl_preservation.mean(0)[0],sl_preservation.std(0)[0],
# Out:
# (0.76003596919934258, 0.062407004788516261)

# %%
combined = np.vstack((D[0],D_true)).T

# %%
plt.scatter(D[0],D_true,linewidths=0,alpha=0.5)
plt.xlabel('Cophenetic distance in embedding')
plt.ylabel('Cophenetic distance in data')
plt.xaxis('log')

# %%
np.vstack((D[0],D_true)).T.shape
# Out:
# (1613706, 2)

# %%
import seaborn as sns
sns.kdeplot(combined[npr.rand(len(combined))<0.01])

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_s)

# %%
d_pca = hierarchy.cophenet(hierarchy.linkage(X_pca,'single'))

# %%
spearmanr(D_true,d_pca)
# Out:
# (0.0054284401836462047, 5.3529792161293164e-12)

# %%
import density_estimation

# %%
plt.scatter(D_true,d_pca,linewidths=0,alpha=0.5)

# %%
from sklearn.manifold import TSNE
tsne = TSNE()
X_tsne = tsne.fit_transform(X_s)
d_tsne = hierarchy.cophenet(hierarchy.linkage(X_tsne,'single'))

# %%
plt.scatter(D_true,d_tsne)

# %%
spearmanr(D_true,d_tsne)
# Out:
# (0.33953085176246123, 0.0)

# %%
linkage = 'complete'
d_true = hierarchy.cophenet(hierarchy.linkage(X_s,linkage))
d_tsne = hierarchy.cophenet(hierarchy.linkage(X_tsne,linkage))
spearmanr(d_true,d_tsne)
# Out:
# (0.23740972664593771, 0.0)

# %%
d_true = hierarchy.cophenet(hierarchy.linkage(X_s,linkage))
d_single = hierarchy.cophenet(hierarchy.linkage(X_[0],linkage))
spearmanr(d_true,d_single)
# Out:
# (0.106042915754215, 0.0)

# %%
spearmanr(D[1],D[0])
# Out:
# (0.63807976967737778, 0.0)

# %%
np.array(D).shape
# Out:
# (10, 499500)

# %%
spearmanr(pdist(X_s),pdist(X_[0]))
# Out:
# (0.14688289088167644, 0.0)

# %%
spearmanr(npr.rand(len(D_true)),npr.rand(len(D_true)))
# Out:
# (-0.001165309677910792, 0.41017569073697491)

# %%
from sklearn.decomposition import KernelPCA
kpca = KernelPCA(n_components=2,kernel='rbf',gamma=0.05)
X_kpca = kpca.fit_transform(X)

# %%
D_true = dict()

for linkage in linkages:
    D_true[linkage] = hierarchy.cophenet(hierarchy.linkage(X_s,linkage))

# %%
D_kpca = dict()
for linkage in linkages:
    print(linkage)
    d_true = D_true[linkage]
    d_kpca = hierarchy.cophenet(hierarchy.linkage(X_kpca,linkage))
    D_kpca[linkage] = d_kpca
    print(spearmanr(d_true,d_kpca))
# Out:
# single
# (-0.014253993119740294, 2.7558189597601987e-73)
# complete
# (0.006274895061095717, 1.5716647611090922e-15)
# ward
# (0.014700368009014482, 7.8903412869512576e-78)
# average
# (-0.0044712580453414343, 1.3474171503028061e-08)
# weighted
# (-0.033131027340033647, 0.0)
# centroid
# (-0.0050852301332131589, 1.0477739498516777e-10)
# median
# (-0.0055413983921693728, 1.9309330319403594e-12)

# %%
D_tsne = dict()
for linkage in linkages:
    print(linkage)
    d_true = D_true[linkage]
    d_tsne = hierarchy.cophenet(hierarchy.linkage(X_tsne,linkage))
    D_tsne[linkage] = d_tsne
    print(spearmanr(d_true,d_tsne))
# Out:
# single
# (0.33953085176246123, 0.0)
# complete
# (0.23740972664593771, 0.0)
# ward
# (0.39684425523422129, 0.0)
# average
# (0.33417617310011649, 0.0)
# weighted
# (0.24262654632821276, 0.0)
# centroid
# (0.26673143246329378, 0.0)
# median
# (0.16216800345384705, 0.0)

# %%
hierarchy.cophenet(C[0])
# Out:
# (499500,)

# %%
C[0]
# Out:
# array([[  4.37000000e+02,   4.86000000e+02,   1.80252320e-01,
#           2.00000000e+00],
#        [  1.27000000e+02,   9.12000000e+02,   1.85243762e-01,
#           2.00000000e+00],
#        [  8.90000000e+02,   9.18000000e+02,   1.90887479e-01,
#           2.00000000e+00],
#        ...,
#        [  3.50000000e+01,   1.99500000e+03,   4.22645481e+00,
#           9.98000000e+02],
#        [  3.05000000e+02,   1.99600000e+03,   4.37952780e+00,
#           9.99000000e+02],
#        [  5.97000000e+02,   1.99700000e+03,   4.59068060e+00,
#           1.00000000e+03]])

# %%
hierarchy.linkage()

# %%
compare_pairwise_distances(X_[0],X_[1])
# Out:
# 52076478.112204485

# %%
# compare the hierarchical clusterings induced by each of several embeddings

# %%
import comparing_embeddings
from comparing_embeddings import multi_linkage_cophenetic_preservation

# %%
import imp
imp.reload(comparing_embeddings)
# Out:
# <module 'comparing_embeddings' from '../scripts/comparing_embeddings.py'>

# %%
multi_linkage_cophenetic_preservation(X_[0],X_[1])
# Out:
# array([ 0.63807977,  0.30378927,  0.27254494,  0.39485661,  0.18520064,
#         0.40484464,  0.14032704])

# %%
multi_linkage_cophenetic_preservation(X_[0],X_[1])
